# %% [markdown]
# The Customer Shopping Preferences Dataset offers valuable insights into consumer behavior and purchasing patterns. Understanding customer preferences and trends is critical for businesses to tailor their products, marketing strategies, and overall customer experience.

# %% [markdown]
# ### IMPORTING LIBRARIES

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### LOADING DATASET

# %%
df = pd.read_csv("shopping_trends.csv")
df
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# ...

# %%
# make a copy of dataset
dataset = df.copy()

# %% [markdown]
# ### ABOUT THE DATASET

# %%
print("number of rows and columns: ",df.shape)
# Out:
# number of rows and columns:  (3900, 19)

# %%
print("number of elements: ",df.size)
# Out:
# number of elements:  74100

# %%
df.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Payment Method',
#        'Shipping Type', 'Discount Applied', 'Promo Code Used',
#        'Previous Purchases', 'Preferred Payment Method',
#        'Frequency of Purchases'],
#       dtype='object')

# %% [markdown]
#      Customer ID - Unique identifier for each customer.
#      Age - Age of the customer.
#      Item Purchased - The item purchased by the customer.
#      Category - Category of the item purchased.
#      Purchase Amount (USD) - The amount of the purchase in USD.
#      Location - Location where the purchase was made.
#      Size - Size of the purchased item.
#      Color - Color of the purchased item.
#      Season - Season during which the purchase was made.
#      Review Rating - Rating given by the customer for the purchased item.
#      Subscription Status - Indicates if the customer has a subscription (Yes/No).
#      Shipping Type - Type of shipping chosen by the customer.
#      Discount Applied - Indicates if a discount was applied to the purchase (Yes/No).
#      Promo Code Used - Indicates if a promo code was used for the purchase (Yes/No).
#      Previous Purchases - Number of previous purchases made by the customer.
#      Payment Method - Customer's most preferred payment method.
#      Frequency of Purchases - Frequency at which the customer makes purchases (e.g., Weekly, Fortnightly, Monthly).

# %%
print("data types of each columns: \n",df.dtypes)
# Out:
# data types of each columns:
#  Customer ID                   int64
# Age                           int64
# Gender                       object
# Item Purchased               object
# Category                     object
# Purchase Amount (USD)         int64
# Location                     object
# Size                         object
# Color                        object
# Season                       object
# Review Rating               float64
# Subscription Status          object
# Payment Method               object
# Shipping Type                object
# Discount Applied             object
# Promo Code Used              object
# Previous Purchases            int64
# Preferred Payment Method     object
# Frequency of Purchases       object
# dtype: object

# %% [markdown]
# ### MISSING VALUES

# %%
df.isnull().sum()
# Out:
# Customer ID                 0
# Age                         0
# Gender                      0
# Item Purchased              0
# Category                    0
# Purchase Amount (USD)       0
# Location                    0
# Size                        0
# Color                       0
# Season                      0
# Review Rating               0
# Subscription Status         0
# Payment Method              0
# Shipping Type               0
# Discount Applied            0
# Promo Code Used             0
# Previous Purchases          0
# Preferred Payment Method    0
# Frequency of Purchases      0
# dtype: int64

# %% [markdown]
# ### DUPLICATES

# %%
df.duplicated().any()
# Out:
# False

# %% [markdown]
# - there is no missing values in the dataset
# - there is no duplicates in the dataset

# %% [markdown]
# ### DESCRIPTIVE ANALYSIS

# %%
df.describe()
# Out:
#        Customer ID          Age  Purchase Amount (USD)  Review Rating  \
# count  3900.000000  3900.000000            3900.000000    3900.000000
# mean   1950.500000    44.068462              59.764359       3.749949
# std    1125.977353    15.207589              23.685392       0.716223
# min       1.000000    18.000000              20.000000       2.500000
# 25%     975.750000    31.000000              39.000000       3.100000
# 50%    1950.500000    44.000000              60.000000       3.700000
# 75%    2925.250000    57.000000              81.000000       4.400000
# max    3900.000000    70.000000             100.000000       5.000000
#
#        Previous Purchases
# count         3900.000000
# mean            25.351538
# std             14.447125
# min              1.000000
# 25%             13.000000
# 50%             25.000000
# 75%             38.000000
# max             50.000000

# %% [markdown]
# - count is `3900` for all(there is no null values)
# - median age is 44
# - max  age is 70 and min age is 18
# - max purchased amount is 100
# - min purchase amount is 20

# %% [markdown]
# ### UNIVARIABLE ANALYSIS

# %%
df.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Payment Method',
#        'Shipping Type', 'Discount Applied', 'Promo Code Used',
#        'Previous Purchases', 'Preferred Payment Method',
#        'Frequency of Purchases'],
#       dtype='object')

# %% [markdown]
# ###### age

# %%
sns.boxplot(x="Age",data=df)
plt.title("variance of age")
plt.xlabel("AGE")
plt.show()

# %% [markdown]
# - there is no outliers which means that the customers age group is 20-70

# %% [markdown]
# ###### gender

# %%
sns.countplot(x="Gender", data=df)
plt.title("Distribution of Genders")
plt.xlabel("Gender")
plt.show()

# %% [markdown]
# - male purchased more than female

# %% [markdown]
# ### category

# %%
sns.countplot(data=df,x="Category")
plt.title("category of items")
plt.xlabel("CATEGORY")
plt.show()

# %% [markdown]
# - category clothing is more than others
# - outerwears are compartively few purchased

# %% [markdown]
# ###### Item purchased

# %%
sns.countplot(y="Item Purchased",data=df)
plt.title("item purchased")
plt.ylabel("ITEM")
plt.grid()
plt.show()

# %%
df["Item Purchased"].nunique()
# Out:
# 25

# %%
plt.figure(figsize = (20, 6))
df["Item Purchased"].value_counts().plot(kind = 'bar')
plt.title("item purchased")
plt.xlabel("ITEM")
plt.show()

# %%
df["Item Purchased"].value_counts(ascending=False)
# Out:
# Blouse        171
# Jewelry       171
# Pants         171
# Shirt         169
# Dress         166
# Sweater       164
# Jacket        163
# Belt          161
# Sunglasses    161
# Coat          161
# Sandals       160
# Socks         159
# Skirt         158
# Shorts        157
# Scarf         157
# Hat           154
# Handbag       153
# Hoodie        151
# Shoes         150
# T-shirt       147
# Sneakers      145
# Boots         144
# Backpack      143
# Gloves        140
# Jeans         124
# Name: Item Purchased, dtype: int64

# %% [markdown]
# - blouse,jeweller,pants is purchased more

# %% [markdown]
# ###### Purchase Amount (USD)

# %%
sns.boxplot(x="Purchase Amount (USD)",data=df)
plt.title("variance of amount")
plt.xlabel("Purchase Amount(USD)")
plt.show()

# %% [markdown]
# - min purchased amount is 20 and maximum purchased  amount is 100
# - there is no outliers,that is amount varies from 20-100

# %% [markdown]
# ###### Location

# %%
df["Location"].value_counts()[:10].sort_values(ascending = False).head(6).plot(kind = 'bar')
plt.title("different location")
plt.xlabel("location")
plt.show()

# %%
df["Location"].value_counts().sort_values(ascending = False)
# Out:
# Montana           96
# California        95
# Idaho             93
# Illinois          92
# Alabama           89
# Minnesota         88
# Nebraska          87
# New York          87
# Nevada            87
# Maryland          86
# Delaware          86
# Vermont           85
# Louisiana         84
# North Dakota      83
# West Virginia     81
# New Mexico        81
# Missouri          81
# Mississippi       80
# Indiana           79
# Georgia           79
# Kentucky          79
# Arkansas          79
# North Carolina    78
# Connecticut       78
# Texas             77
# Maine             77
# Ohio              77
# Tennessee         77
# Virginia          77
# South Carolina    76
# Colorado          75
# Oklahoma          75
# Wisconsin         75
# Oregon            74
# Pennsylvania      74
# Washington        73
# Michigan          73
# Massachusetts     72
# Alaska            72
# Wyoming           71
# Utah              71
# New Hampshire     71
# South Dakota      70
# ...

# %% [markdown]
# - purchasing is occured more in Montana(96) and California(95)

# %%
plt.figure(figsize = (20, 6))
df["Size"].value_counts().plot(kind = 'bar')
plt.title("different size")
plt.xlabel("different size")

plt.show()

# %% [markdown]
# - medium size is purchased more

# %% [markdown]
# ###### COLOR

# %%
plt.figure(figsize = (16, 6))
df["Color"].value_counts()[:10].sort_values(ascending = True).plot(kind = 'barh', edgecolor = 'black')
plt.ylabel('Color')
plt.xlabel('Number of Occurrences');
plt.title("color distribution")
plt.show()

# %% [markdown]
# - Olive color is most purchased

# %% [markdown]
# ###### season

# %%
df["Season"].value_counts().plot(kind = 'bar')

plt.xlabel('Season')
plt.title("different season")
plt.show()

# %%
df["Season"].value_counts()
# Out:
# Spring    999
# Fall      975
# Winter    971
# Summer    955
# Name: Season, dtype: int64

# %% [markdown]
# - all seasons performed well

# %% [markdown]
# ###### shipping type

# %%
df["Shipping Type"].value_counts()
# Out:
# Free Shipping     675
# Standard          654
# Store Pickup      650
# Next Day Air      648
# Express           646
# 2-Day Shipping    627
# Name: Shipping Type, dtype: int64

# %%
df["Shipping Type"].value_counts().plot(kind = 'bar')

plt.xlabel('Shipping Type')
plt.title("Shipping Type")
plt.show()

# %% [markdown]
# - items delivered more by free shipping method

# %% [markdown]
# ###### Discount Applied

# %%
df["Discount Applied"].value_counts().plot(kind = 'bar')

plt.xlabel('discount')
plt.title("Disount Applied")
plt.show()

# %% [markdown]
# - discount provided is less

# %% [markdown]
# ###### Review Rating

# %%
df["Review Rating"].value_counts().plot(kind = 'bar')

plt.xlabel('Review Rating')
plt.title("Review Rating")
plt.show()

# %% [markdown]
# - max Review Rating is 3.4 and min is 2.5

# %% [markdown]
# ###### Subscription Status

# %%
df["Subscription Status"].value_counts().plot(kind = 'bar')

plt.xlabel('Subscription Status')
plt.title("Subscription Status")
plt.show()

# %% [markdown]
# - few customers suscribed

# %% [markdown]
# ###### Payment Method

# %%
df["Payment Method"].value_counts().plot(kind = 'bar')

plt.xlabel('Payment Method')
plt.title("Payment Method")
plt.show()

# %% [markdown]
# - most of the payment is done through credit card transactions

# %% [markdown]
# ###### Promo Code Used

# %%
df["Promo Code Used"].value_counts().plot(kind = 'bar')

plt.xlabel('Promo Code Used')
plt.title("Promo Code Used")
plt.show()

# %% [markdown]
# - most customers purchased without promo code

# %% [markdown]
# ###### Previous Purchases

# %%
df["Previous Purchases"].value_counts()[:15]
# Out:
# 31    97
# 21    96
# 14    92
# 24    91
# 3     91
# 4     91
# 48    90
# 47    90
# 5     87
# 6     87
# 18    84
# 20    83
# 45    83
# 42    83
# 1     83
# Name: Previous Purchases, dtype: int64

# %%
df["Previous Purchases"].value_counts()[:15].plot(kind = 'barh')

plt.ylabel('Previous Purchases')
plt.title("Previous Purchases")
plt.show()

# %% [markdown]
# - 31th customer have previous purchased history more

# %% [markdown]
# ###### Frequency of Purchases

# %%
df["Frequency of Purchases"].value_counts().plot(kind = 'bar')

plt.xlabel('Frequency of Purchases')
plt.title("Frequency of Purchases")
plt.show()

# %% [markdown]
# - purchasing was higher at every 3 months

# %% [markdown]
# ### gender and item purchased

# %%
plt.figure(figsize = (10,4))
sns.countplot(data = df, x = "Item Purchased",  hue = "Gender")
plt.title("gender and item purchased")
plt.xlabel("item")
plt.legend(["male", "female"])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - male purchased more than female

# %% [markdown]
# ### Box Plot of Purchase Amount by Gender

# %%
plt.figure(figsize = (20, 6))
sns.boxplot(x='Gender', y='Purchase Amount (USD)', data=df)
plt.title('Purchase Amount by Gender')
plt.xlabel('Gender')
plt.ylabel('Purchase Amount (USD)')
plt.show()

# %% [markdown]
# ### Payment Method by Season

# %%
plt.figure(figsize=(20, 6))
sns.barplot(x='Season', y='Purchase Amount (USD)', hue='Payment Method', data=df)
plt.title('Purchase Amount by Season and Payment Method')
plt.xlabel('Season')
plt.ylabel('Purchase Amount (USD)')
plt.xticks(rotation = 0)
plt.show()

# %% [markdown]
# - payment method varies according to season

# %% [markdown]
# UNIVARIABLE ANALYSIS
# - the customers age group is 20-70
# - male purchased more than female
# - category clothing is more than others and outerwears are compartively few purchased
# - blouse,jeweller,pants is purchased more
# - min purchased amount is 20 and maximum purchased  amount is 100
# - purchasing is occured more in Montana(96) and California(95)
# - medium size is purchased more
# - Olive color is most purchased
# - all seasons performed well
# - discount provided is less
# - max Review Rating is 3.4 and min is 2.
# - few customers suscribed
# - most of the payment is done through credit card transactions
# - items delivered more by free shipping method
# - most customers purchased without promo code
# - 31th customer have previous purchased history more
# - purchasing was higher at every 3 months
# - payment method varies according to season
